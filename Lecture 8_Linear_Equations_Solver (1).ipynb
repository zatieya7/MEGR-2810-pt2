# %% [markdown]
# # A. Basics of Linear Algebra to Solve Systems of Equations
#
# **Goals**
# - Understand how to represent a linear system in matrix form $A\mathbf{x}=\mathbf{b}$.
# - Diagnose when a system has a unique solution, infinitely many solutions, or no solution.
# - Use NumPy to compute ranks, determinants, and solve or analyze systems.
# - See geometric intuition in 2D (lines) and learn core algorithms (Gaussian elimination).

# %%
# Add this to your cells to import commonly used libraries
import numpy as np
from numpy.linalg import matrix_rank, det, solve, lstsq, inv
import matplotlib.pyplot as plt
np.set_printoptions(suppress=True, precision=4)

# %% [markdown]
# ### 1. Linear systems and matrix form
# A linear system with unknown vector $\mathbf{x} \in \mathbb{R}^n$ can be written as $A\mathbf{x} = \mathbf{b},$ where $A \in \mathbb{R}^{m\times n}$ is the coefficient matrix and $\mathbf{b} \in \mathbb{R}^m$.
#
# **Augmented matrix**: $[A\mid \mathbf{b}]$ is useful for row-reduction (Gaussian elimination).

# %% [markdown]
# In this example below, we have two equations:
# x + y + z = 3 & 2x -y -3z = 0

# %%
# Add comments yourself!!! 
# A small example system

import numpy as np
# Create matrix A representing the coefficients of the system of equations
# Each row represents one equation, and each column represents one variable. 
A = np.array([[1., 1., 1.], [2., -1., -3]])
b = np.array([3., 0.])#[:, None]
# Show what A looks like
print('A =\n', A)
# Show what B looks like
# Combine A and b into one big matrix [A|b] (called the "augmented matrix")
# This makes it easier to solve the system later
print('b =\n', b)
aug = np.c_[A, b]  # Syntax to create augmented matrix [A|b]
print('Augmented [A|b] =\n', aug)
# Out:
# A =
#  [[ 1.  1.  1.]
#  [ 2. -1. -3.]]
# b =
#  [3. 0.]
# Augmented [A|b] =
#  [[ 1.  1.  1.  3.]
#  [ 2. -1. -3.  0.]]

# %% [markdown]
# ### 2. Types of solutions and rank conditions
# Let $r = \operatorname{rank}(A)$ and $r_a = \operatorname{rank}([A\mid \mathbf{b}])$.
# - **Unique solution**: $r = r_a = n$.
# - **Infinitely many solutions**: $r = r_a < n$.
# - **No solution** (inconsistent): $r \neq r_a$.
#
# For a square system ($m=n$): $\det(A) \neq 0$ $\Rightarrow$ unique solution; if $\det(A)=0$, then either infinitely many or none (check consistency).

# %% [markdown]
# #### 2.1 Unique solution example
# We have two equations in the example below: x + y = 3 & 2x - y = 0. That's why we have a unique solution.

# %%
A1 = np.array([[1., 1.], [2., -1.]])
b1 = np.array([3., 0.])
rA1 = matrix_rank(A1)
rAug1 = matrix_rank(np.c_[A1, b1])
print('rank(A)=', rA1, ' rank([A|b])=', rAug1)
print('det(A)=', det(A1))
# Out:
# rank(A)= 2  rank([A|b])= 2
# det(A)= -2.9999999999999996

# %% [markdown]
# Exercise-
# Plot these two functions in the same plot

# %%
# Create x values (from -10 to 10)
x = np.linspace(-10, 10, 100)

# Define two functions
y1 = x**2              # First function: y = x²
y2 = np.sin(x)         # Second function: y = sin(x)

# Make the plot
plt.plot(x, y1, label="y = x²")      # Plot the first function
plt.plot(x, y2, label="y = sin(x)")  # Plot the second function

# Add a title and labels
plt.title("Two Functions on the Same Plot")
plt.xlabel("x values")
plt.ylabel("y values")

# Add a legend to tell which line is which
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# #### 2.2 Infinitely many solutions example
# In this example, the second equation is a multiple of the first.

# %%
A2 = np.array([[1., 1.], [2., 2.]])
b2 = np.array([2., 4.])
rA2 = matrix_rank(A2)
rAug2 = matrix_rank(np.c_[A2, b2])
print('rank(A)=', rA2, ' rank([A|b])=', rAug2)
print('det(A)=', det(A2))
# Out:
# rank(A)= 1  rank([A|b])= 1
# det(A)= 0.0

# %% [markdown]
# Exercise-
#
# Plot there two functions together in one plot: x + y = 2 & 2x + 2y = 4

# %%
# Show the plot
plt.show()
# Import the libraries
import numpy as np
import matplotlib.pyplot as plt

# Create x values (numbers for x-axis)
x = np.linspace(-5, 5, 100)

# Equation 1: x + y = 2  →  y = 2 - x
y1 = 2 - x

# Equation 2: 2x + 2y = 4  →  divide both sides by 2 → y = 2 - x
y2 = 2 - x  # (same line, but we plot it again to compare)

# Make the plot
plt.plot(x, y1, label='x + y = 2', color='blue')
plt.plot(x, y2, label='2x + 2y = 4', color='red', linestyle='--')

# Add a title and labels
plt.title('Plot of x + y = 2 and 2x + 2y = 4')
plt.xlabel('x values')
plt.ylabel('y values')

# Add a grid to make it easier to read
plt.grid(True)

# Add a legend so we know which line is which
plt.legend()

# Show the graph
plt.show()

# %% [markdown]
# #### 2.3 No solution example
# Parallel lines (inconsistent).

# %%
A3 = np.array([[1., 1.], [2., 2.]])
b3 = np.array([2., 5.])
rA3 = matrix_rank(A3)
rAug3 = matrix_rank(np.c_[A3, b3])
print('rank(A)=', rA3, ' rank([A|b])=', rAug3, ' => inconsistent')
print('det(A)=', det(A3))
# Out:
# rank(A)= 1  rank([A|b])= 2  => inconsistent
# det(A)= 0.0

# %% [markdown]
# Exercise-
#
# Plot these two functions toghether in one plot: x + y = 2 & 2x + 2y = 5

# %%
# Import what we need
import numpy as np
import matplotlib.pyplot as plt

# Create x values (this is our x-axis)
x = np.linspace(-5, 5, 100)

# Equation 1: x + y = 2  →  y = 2 - x
y1 = 2 - x

# Equation 2: 2x + 2y = 5  →  divide both sides by 2 → y = 2.5 - x
y2 = 2.5 - x

# Make the plot
plt.plot(x, y1, label='x + y = 2', color='blue')      # First line
plt.plot(x, y2, label='2x + 2y = 5', color='red')     # Second line

# Add labels and title
plt.title('Plot of x + y = 2 and 2x + 2y = 5')
plt.xlabel('x values')
plt.ylabel('y values')

# Add grid and legend
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # B. Solving Systems of Linear Equations with Python
# We will explore various methods for solving systems of linear equations using Python. We will cover
#
# 1. Solving systems using `numpy.linalg.solve` and matrix inversion
# 2. Gauss Elimination
# 3. Iterative methods like Gauss-Seidel
# 4. Least squares method

# %% [markdown]
# ## 1. Types of Solutions to Linear Systems
# - Unique solution
# - Infinite solutions
# - No solution
# - Geometric interpretation
# - Role of rank and determinant

# %% [markdown]
# ### Geometric interpretation in 2D
# - Unique solution: two lines intersect at one point.
# - Infinite solutions: coincident lines.
# - No solution: parallel, distinct lines.

# %% [markdown]
# ## 2. Direct Methods
# ### a. Using `np.linalg.solve`
# When 1.)The coefficient matrix A is square (same number of equations as unknowns). 2.) The matrix A is full rank (i.e., its determinant is non-zero).
#
# Don't use when 1.) The matrix is not square. 2.)The matrix is singular (determinant is zero). 3.)The system has no solution or infinitely many solutions.

# %%
import numpy as np
A = np.array([[2, 1], [1, 3]])
b = np.array([8, 13])
print("A=", A)
print("b=", b)
print("Augmented Matrix [A|b] =\n", np.c_[A, b])
print('rank(A)=', matrix_rank(A), ' rank([A|b])=', matrix_rank(np.c_[A, b]))
print('det(A)=', det(A))
x = np.linalg.solve(A, b)
print("Solution:\n", x)
# Out:
# A= [[2 1]
#  [1 3]]
# b= [ 8 13]
# Augmented Matrix [A|b] =
#  [[ 2  1  8]
#  [ 1  3 13]]
# rank(A)= 2  rank([A|b])= 2
# det(A)= 5.000000000000001
# Solution:
#  [2.2 3.6]

# %% [markdown]
# ### b. Matrix Inversion
# Determinant and invertibility (square systems)
# If $\det(A) \neq 0$, then $A$ is invertible and the unique solution is $\mathbf{x}=A^{-1}\mathbf{b}$. If $\det(A)=0$, the system is either inconsistent or has infinitely many solutions.

# %%
A = np.array([[2, 1], [1, 3]])
b = np.array([8, 13])
print('det(A)=', det(A))

# Solve using inversion (A is square and invertible here) and show result
x = np.linalg.inv(A) @ b
print("Solution via inversion:", x)
# Out:
# det(A)= 5.000000000000001
# Solution via inversion: [2.2 3.6]

# %% [markdown]
# ## 3. Gaussian Elimination
# Manual row operations to echelon form and back-substitution.
# Below is a simple implementation with partial pivoting to reach (upper) row-echelon form and solve when a unique solution exists.

# %% [markdown]
# ### Example-
# Let's solve this system of equation:
#
# 2x + y - z = 8
#
# -3x - y + 2z = -11
#
# -2x + y + 2z = -3

# %%
# Your code here for Gaussian elimination step by step
# Print out the augmented matrix at each step

import numpy as np
A = np.array([[2., 1., -1.], 
              [3., 3., 9.], 
              [3., 4., 2.]])
b = np.array([8., 0., -5.])

# Step 1: Initial Augmented Matrix
aug = np.c_[A, b]

print("Step 1: Initial Augmented Matrix")
print(aug)

# Step 2: Make pivot A[0][0] = 1
aug[0] = aug[0] / aug[0][0]
print("\nStep 2: Make pivot A[0][0] = 1")
print(aug)

# Step 3: Eliminate A[1][0] using row 0
aug[1] = aug[1] - 3 * aug[0]
print("\nStep 3: Eliminate A[1][0] using row 0")
print(aug)

# Step 4: Eliminate A[2][0] using row 0
factor = aug[2][0]        # fixed: use actual value, not just 3
aug[2] = aug[2] - factor * aug[0]
print("\nStep 4: Eliminate A[2][0] using row 0")
print(aug)


# Step 5: Make pivot A[1][1] = 1
aug[1] = aug[1] / aug[1][1]
print("\nStep 5: Make pivot A[1][1] = 1")
print(aug)

# Step 6: Eliminate A[2][1] using row 1
aug[2] = aug[2] - aug[2][1] * aug[1]
print("\nStep 6: Eliminate A[2][1] using row 1")
print(aug)

# Step 7: Make pivot A[2][2] = 1
aug[2] = aug[2] / aug[2][2]
print("\nStep 7: Make pivot A[2][2] = 1")
print(aug)

# Step 8: Back substitution to get final solution
print("\nStep 8: Final Augmented Matrix after Elimination")
print(aug)
# Out:
# Step 1: Initial Augmented Matrix
# [[ 2.  1. -1.  8.]
#  [ 3.  3.  9.  0.]
#  [ 3.  4.  2. -5.]]
#
# Step 2: Make pivot A[0][0] = 1
# [[ 1.   0.5 -0.5  4. ]
#  [ 3.   3.   9.   0. ]
#  [ 3.   4.   2.  -5. ]]
#
# Step 3: Eliminate A[1][0] using row 0
# [[  1.    0.5  -0.5   4. ]
#  [  0.    1.5  10.5 -12. ]
#  [  3.    4.    2.   -5. ]]
#
# Step 4: Eliminate A[2][0] using row 0
# [[  1.    0.5  -0.5   4. ]
#  [  0.    1.5  10.5 -12. ]
#  [  0.    2.5   3.5 -17. ]]
#
# Step 5: Make pivot A[1][1] = 1
# [[  1.    0.5  -0.5   4. ]
#  [  0.    1.    7.   -8. ]
#  [  0.    2.5   3.5 -17. ]]
#
# Step 6: Eliminate A[2][1] using row 1
# [[  1.    0.5  -0.5   4. ]
#  [  0.    1.    7.   -8. ]
#  [  0.    0.  -14.    3. ]]
#
# Step 7: Make pivot A[2][2] = 1
# [[ 1.      0.5    -0.5     4.    ]
#  [ 0.      1.      7.     -8.    ]
#  [-0.     -0.      1.     -0.2143]]
#
# Step 8: Final Augmented Matrix after Elimination
# [[ 1.      0.5    -0.5     4.    ]
#  [ 0.      1.      7.     -8.    ]
#  [-0.     -0.      1.     -0.2143]]

# %% [markdown]
# Exercise-
#
# Use loops to do the foward elimination (i.e., make pivot and eliminate) and the back substitution for Gaussian Elimination. Draw a flow chart first.

# %%
import numpy as np

# Coefficient matrix A and constant vector b
A = np.array([[2., 1., -1.],
              [3., 3., 9.],
              [3., 4., 2.]])
b = np.array([8., 0., -5.])

# Combine A and b into one augmented matrix [A|b]
aug = np.c_[A, b]
n = len(b)

print("Initial Augmented Matrix [A|b]:")
print(aug)

# Forward Elimination 
for i in range(n):  # Loop through each pivot row
    # Make pivot = 1 (divide row i by pivot value)
    pivot = aug[i][i]
    aug[i] = aug[i] / pivot
    print(f"\nStep {i+1}: Make pivot in row {i+1} = 1")
    print(aug)

    # Eliminate below the pivot
    for j in range(i+1, n):
        factor = aug[j][i]
        aug[j] = aug[j] - factor * aug[i]
        print(f"Eliminate A[{j}][{i}] using row {i+1}")
        print(aug)

#  Back Substitution 
x = np.zeros(n)
for i in range(n-1, -1, -1):
    x[i] = aug[i][-1] - np.sum(aug[i, i+1:n] * x[i+1:n])

print("\nFinal Augmented Matrix in Row Echelon Form:")
print(aug)

print("\nSolution (x, y, z):")
print(x)
# Out:
# Initial Augmented Matrix [A|b]:
# [[ 2.  1. -1.  8.]
#  [ 3.  3.  9.  0.]
#  [ 3.  4.  2. -5.]]
#
# Step 1: Make pivot in row 1 = 1
# [[ 1.   0.5 -0.5  4. ]
#  [ 3.   3.   9.   0. ]
#  [ 3.   4.   2.  -5. ]]
# Eliminate A[1][0] using row 1
# [[  1.    0.5  -0.5   4. ]
#  [  0.    1.5  10.5 -12. ]
#  [  3.    4.    2.   -5. ]]
# Eliminate A[2][0] using row 1
# [[  1.    0.5  -0.5   4. ]
#  [  0.    1.5  10.5 -12. ]
#  [  0.    2.5   3.5 -17. ]]
#
# Step 2: Make pivot in row 2 = 1
# [[  1.    0.5  -0.5   4. ]
#  [  0.    1.    7.   -8. ]
#  [  0.    2.5   3.5 -17. ]]
# Eliminate A[2][1] using row 2
# [[  1.    0.5  -0.5   4. ]
#  [  0.    1.    7.   -8. ]
#  [  0.    0.  -14.    3. ]]
#
# Step 3: Make pivot in row 3 = 1
# [[ 1.      0.5    -0.5     4.    ]
#  [ 0.      1.      7.     -8.    ]
#  [-0.     -0.      1.     -0.2143]]
#
# Final Augmented Matrix in Row Echelon Form:
# [[ 1.      0.5    -0.5     4.    ]
#  [ 0.      1.      7.     -8.    ]
#  [-0.     -0.      1.     -0.2143]]
#
# Solution (x, y, z):
# [ 7.1429 -6.5    -0.2143]

# %% [markdown]
# ## 4. Iterative Method- Gauss-Seidel
#
#  This method solves a system of linear equations iteratively and prints the updated solution vector at each iteration until convergence.

# %% [markdown]
# Example-
#
# Let's solve this system of equation:
#
# 4x_0 - x_1         = 15
#
# -x_0 - 4x_1 - x_2  = 10
#
#      - x_1  + 3x_2 = 10

# %%
import numpy as np

# Define the system of equations
A = np.array([[4.0, -1.0, 0.0],
              [-1.0, 4.0, -1.0],
              [0.0, -1.0, 3.0]])
b = np.array([15.0, 10.0, 10.0])

# Initial guess
x = np.zeros_like(b)

# Tolerance and maximum iterations
tol = 1e-6
max_iterations = 25

n = len(b)
print ("length of b array=", n)

print("Initial guess:", x)

for k in range(max_iterations):
    x_new = np.copy(x)
    print(f"Iteration {k+1}:")
    for i in range(n):
        s1 = sum(A[i][j] * x_new[j] for j in range(i))
        s2 = sum(A[i][j] * x[j] for j in range(i + 1, n))
        x_new[i] = (b[i] - s1 - s2) / A[i][i]
        print(f"x[{i}] = {x_new[i]}")

    # Check for convergence
    if np.allclose(x, x_new, atol=tol):
        print("Converged!")
        break
    x = x_new

print("Final solution:")
print(x)
# Out:
# length of b array= 3
# Initial guess: [0. 0. 0.]
# Iteration 1:
# x[0] = 3.75
# x[1] = 3.4375
# x[2] = 4.479166666666667
# Iteration 2:
# x[0] = 4.609375
# x[1] = 4.772135416666667
# x[2] = 4.924045138888889
# Iteration 3:
# x[0] = 4.943033854166667
# x[1] = 4.966769748263889
# x[2] = 4.988923249421297
# Iteration 4:
# x[0] = 4.991692437065972
# x[1] = 4.995153921621817
# x[2] = 4.998384640540606
# Iteration 5:
# x[0] = 4.998788480405454
# x[1] = 4.9992932802365155
# x[2] = 4.999764426745505
# Iteration 6:
# x[0] = 4.999823320059129
# x[1] = 4.999896936701158
# x[2] = 4.999965645567053
# Iteration 7:
# x[0] = 4.99997423417529
# x[1] = 4.999984969935586
# x[2] = 4.9999949899785285
# Iteration 8:
# x[0] = 4.999996242483896
# x[1] = 4.999997808115606
# x[2] = 4.999999269371869
# Converged!
# Final solution:
# [5. 5. 5.]

# %% [markdown]
# Exercise-
# Draw the flowchart of the code above.

# %% [markdown]
# ## 5 Least Squares Method
# (Optional for now. We will discuss more later.)
#
#
# Using `np.linalg.lstsq` for least-squares solutions.
# When 1.) The matrix is not square (more equations than unknowns). 2.)The matrix is singular (determinant is zero). 3.)The system has no solution or infinitely many solutions.
#
# When a system of linear equations is **overdetermined** (more equations than unknowns), an exact solution may not exist. In such cases, we also use the **least squares method** to find an approximate solution that minimizes the residual error.
#
# Notes
# - `np.linalg.lstsq` returns the solution vector `x`, residuals, rank of matrix `A`, and singular values.
# - The residuals indicate how close the solution comes to satisfying all equations.
# - Least squares is widely used in **data fitting**, **regression**, and **signal processing**.

# %%
import numpy as np
A = np.array([[1., 1.], [1., 2.], [1, 3]])
b = np.array([1., 2., 2.])[:, None]
print('A =\n', A)
print('b =\n', b)
#print('det(A)=', det(A))
x, residuals, rank, s = lstsq(A, b, rcond=None)
print("Rank(A) =", rank)
print("Singular values of A =", s)
print('Least-squares solution x =', x)
print('Residual ||Ax-b|| =', residuals)
# Out:
# A =
#  [[1. 1.]
#  [1. 2.]
#  [1. 3.]]
# b =
#  [[1.]
#  [2.]
#  [2.]]
# Rank(A) = 2
# Singular values of A = [4.0791 0.6005]
# Least-squares solution x = [[0.6667]
#  [0.5   ]]
# Residual ||Ax-b|| = [0.1667]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define x range
x = np.linspace(-4, 4, 50)

# Define the equations
y1 = 1 - x       # x + y = 1
y2 = (2 - x) / 2 # x + 2y = 2
y3 = (2 - x) / 3 # x + 3y = 2

# Plotting
plt.figure(figsize=(8, 6))
plt.plot(x, y1, label='x + y = 1')
plt.plot(x, y2, label='x + 2y = 2')
plt.plot(x, y3, label='x + 3y = 2')

# Add labels and legend
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of Three Linear Equations')
plt.grid(True)
plt.legend()
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)

# Show plot
plt.show()

# %% [markdown]
# ## 6. Summary Table
# | Method             | Type         | Pros                     | Cons                      |
# |--------------------|--------------|--------------------------|---------------------------|
# | `np.linalg.solve`  | Direct       | Fast, accurate           | Only for square systems   |
# | Inversion          | Direct       | Conceptually simple      | Numerically unstable      |
# | Gauss Elimination  | Manual       | Educational               | Tedious for large systems |
# | Gauss-Seidel       | Iterative    | Good for sparse systems  | Needs convergence check   |
# | Least Squares      | Overdetermined | Handles extra equations | Approximate solution      |

# %% [markdown]
# ## Exercise Problem 1:
# Solve this system of equations using least squares method and plot the three line in one plot.
# 1. \(2x + y = 8\)
# 2. \(x + 3y = 13\)
# 3. \(x + y = 7\) *(Overdetermined)*

# %% [markdown]
# ## Exercise Problem 2
# Create a $3\times 3$ system with a unique solution. Verify using rank and determinant, then solve with `solve`.

# %%
import numpy as np

# Step 1: Create a 3x3 system A x = b
A = np.array([[2, 1, -1],
              [1, 3, 2],
              [3, 4, 1]])
b = np.array([3, 10, 8])

print("Matrix A:")
print(A)
print("\nVector b:")
print(b)

# Step 2: Verify unique solution
rank_A = np.linalg.matrix_rank(A)
rank_aug = np.linalg.matrix_rank(np.c_[A, b])
det_A = np.linalg.det(A)

print(f"\nRank of A: {rank_A}")
print(f"Rank of augmented matrix [A|b]: {rank_aug}")
print(f"Determinant of A: {det_A:.2f}")

if rank_A == rank_aug == 3 and det_A != 0:
    print("Unique solution exists")
else:
    print("No unique solution (system may be dependent or singular)")

# Step 3: Solve the system
x = np.linalg.solve(A, b)
print("\nSolution vector x (x1, x2, x3):")
print(x)

# Optional: Verify by plugging solution back
b_check = A @ x
print("\nCheck A @ x:")
print(b_check)
# Out:
# Matrix A:
# [[ 2  1 -1]
#  [ 1  3  2]
#  [ 3  4  1]]
#
# Vector b:
# [ 3 10  8]
#
# Rank of A: 2
# Rank of augmented matrix [A|b]: 3
# Determinant of A: -0.00
# No unique solution (system may be dependent or singular)
#
# Solution vector x (x1, x2, x3):
# [ 1.3511e+17 -1.3511e+17  1.3511e+17]
#
# Check A @ x:
# [32.  0. 32.]

# %% [markdown]
# ## Exercise Problem 3
# Create an inconsistent system. Compute the least-squares solution and residual norm.

# %%
import numpy as np

# Step 1: Create an inconsistent system A x = b
# Example: 2 equations with 2 unknowns that don't intersect
A = np.array([[1, 1],
              [1, 1.1]])
b = np.array([2, 3])   # This system has no exact solution

print("Matrix A:")
print(A)
print("\nVector b:")
print(b)

# Step 2: Compute least-squares solution
x_ls, residuals, rank, s = np.linalg.lstsq(A, b, rcond=None)

print("\nLeast-squares solution x:")
print(x_ls)

# Step 3: Compute residuals
residual_vector = b - A @ x_ls
residual_norm = np.linalg.norm(residual_vector)  # Euclidean norm

print("\nResidual vector (b - A @ x_ls):")
print(residual_vector)
print(f"\nResidual norm ||b - A x||: {residual_norm:.4f}")
print("Zmoney")
# Out:
# Matrix A:
# [[1.  1. ]
#  [1.  1.1]]
#
# Vector b:
# [2 3]
#
# Least-squares solution x:
# [-8. 10.]
#
# Residual vector (b - A @ x_ls):
# [-0. -0.]
#
# Residual norm ||b - A x||: 0.0000
# Zmoney

# %% [markdown]
# ## Exercise Problem 4
# Use `gaussian_elimination_solve` to solve a new square system and verify the result with `solve`.

# %%
# Your code here
